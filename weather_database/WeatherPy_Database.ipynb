# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | camopi
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | goderich
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | minsk
# Processing Record 10 of Set 1 | longyearbyen
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | lagoa
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | cayenne
# Processing Record 15 of Set 1 | necochea
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | angoche
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | udachnyy
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | lorengau
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | mangan
# Processing Record 27 of Set 1 | naberera
# Processing Record 28 of Set 1 | pilar
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | souillac
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | pacific grove
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | mabaruma
# Processing Record 37 of Set 1 | jinxiang
# Processing Record 38 of Set 1 | padang
# Processing Record 39 of Set 1 | luena
# Processing Record 40 of Set 1 | kungur
# Processing Record 41 of Set 1 | husavik
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | puerto escondido
# Processing Record 44 of Set 1 | umm kaddadah
# Processing Record 45 of Set 1 | vardo
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | laguna
# Processing Record 48 of Set 1 | kaeo
# Processing Record 49 of Set 1 | sitka
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | fort nelson
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | luderitz
# Processing Record 4 of Set 2 | kushiro
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | morant bay
# Processing Record 9 of Set 2 | paidha
# Processing Record 10 of Set 2 | luoyang
# Processing Record 11 of Set 2 | porbandar
# Processing Record 12 of Set 2 | bambous virieux
# Processing Record 13 of Set 2 | sisimiut
# Processing Record 14 of Set 2 | nueve de julio
# Processing Record 15 of Set 2 | peniche
# Processing Record 16 of Set 2 | fairfield
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | katherine
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | kashipur
# Processing Record 24 of Set 2 | saint-michel-des-saints
# Processing Record 25 of Set 2 | tazovskiy
# Processing Record 26 of Set 2 | poum
# Processing Record 27 of Set 2 | duzici
# City not found. Skipping...
# Processing Record 28 of Set 2 | belyy yar
# Processing Record 29 of Set 2 | cherskiy
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | talaya
# Processing Record 32 of Set 2 | provideniya
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | mangit
# Processing Record 35 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 2 | ketchikan
# Processing Record 37 of Set 2 | muisne
# Processing Record 38 of Set 2 | skibbereen
# Processing Record 39 of Set 2 | snihurivka
# Processing Record 40 of Set 2 | ranghulu
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | ewa beach
# Processing Record 45 of Set 2 | gamba
# Processing Record 46 of Set 2 | san jacinto
# Processing Record 47 of Set 2 | bereda
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 2 | upington
# Processing Record 1 of Set 3 | saquarema
# Processing Record 2 of Set 3 | klaksvik
# Processing Record 3 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 4 of Set 3 | san patricio
# Processing Record 5 of Set 3 | ambilobe
# Processing Record 6 of Set 3 | benguela
# Processing Record 7 of Set 3 | vila franca do campo
# Processing Record 8 of Set 3 | vestmanna
# Processing Record 9 of Set 3 | norman wells
# Processing Record 10 of Set 3 | geraldton
# Processing Record 11 of Set 3 | carnarvon
# Processing Record 12 of Set 3 | tatarskaya pishlya
# Processing Record 13 of Set 3 | saldanha
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | carlsbad
# Processing Record 16 of Set 3 | becerril
# Processing Record 17 of Set 3 | solnechnyy
# Processing Record 18 of Set 3 | manhattan
# Processing Record 19 of Set 3 | vila velha
# Processing Record 20 of Set 3 | yulara
# Processing Record 21 of Set 3 | nunguan
# Processing Record 22 of Set 3 | cidreira
# Processing Record 23 of Set 3 | lompoc
# Processing Record 24 of Set 3 | ballina
# Processing Record 25 of Set 3 | nikolskoye
# Processing Record 26 of Set 3 | grindavik
# Processing Record 27 of Set 3 | qaanaaq
# Processing Record 28 of Set 3 | hunucma
# Processing Record 29 of Set 3 | upernavik
# Processing Record 30 of Set 3 | coihaique
# Processing Record 31 of Set 3 | north battleford
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 3 | timra
# Processing Record 35 of Set 3 | ixtapa
# Processing Record 36 of Set 3 | sao filipe
# Processing Record 37 of Set 3 | port blair
# Processing Record 38 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 3 | pozo colorado
# Processing Record 40 of Set 3 | college
# Processing Record 41 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 3 | kruisfontein
# Processing Record 43 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 44 of Set 3 | gigmoto
# Processing Record 45 of Set 3 | avarua
# Processing Record 46 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 47 of Set 3 | khorixas
# Processing Record 48 of Set 3 | frasinet
# Processing Record 49 of Set 3 | saint george
# Processing Record 50 of Set 3 | vieques
# Processing Record 1 of Set 4 | sawakin
# Processing Record 2 of Set 4 | mayo
# Processing Record 3 of Set 4 | gushikawa
# Processing Record 4 of Set 4 | grand gaube
# Processing Record 5 of Set 4 | lebu
# Processing Record 6 of Set 4 | port macquarie
# Processing Record 7 of Set 4 | tuatapere
# Processing Record 8 of Set 4 | dikson
# Processing Record 9 of Set 4 | saskylakh
# Processing Record 10 of Set 4 | valverde del camino
# Processing Record 11 of Set 4 | okhotsk
# Processing Record 12 of Set 4 | nagtipunan
# Processing Record 13 of Set 4 | high level
# Processing Record 14 of Set 4 | mayumba
# Processing Record 15 of Set 4 | ilulissat
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | tankhoy
# Processing Record 18 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 4 | hasaki
# Processing Record 20 of Set 4 | mozirje
# Processing Record 21 of Set 4 | saraza
# Processing Record 22 of Set 4 | fujin
# Processing Record 23 of Set 4 | sechura
# Processing Record 24 of Set 4 | surab
# Processing Record 25 of Set 4 | beidao
# Processing Record 26 of Set 4 | viedma
# Processing Record 27 of Set 4 | hastings
# Processing Record 28 of Set 4 | barrow
# Processing Record 29 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | bathsheba
# Processing Record 32 of Set 4 | la ronge
# Processing Record 33 of Set 4 | bengkulu
# Processing Record 34 of Set 4 | conde
# Processing Record 35 of Set 4 | colac
# Processing Record 36 of Set 4 | omsukchan
# Processing Record 37 of Set 4 | trat
# Processing Record 38 of Set 4 | marivan
# Processing Record 39 of Set 4 | gao
# Processing Record 40 of Set 4 | jalu
# Processing Record 41 of Set 4 | muros
# Processing Record 42 of Set 4 | xiangdong
# City not found. Skipping...
# Processing Record 43 of Set 4 | qaqortoq
# Processing Record 44 of Set 4 | adrar
# Processing Record 45 of Set 4 | kijang
# Processing Record 46 of Set 4 | tezu
# Processing Record 47 of Set 4 | mastic beach
# Processing Record 48 of Set 4 | luanda
# Processing Record 49 of Set 4 | taoudenni
# Processing Record 50 of Set 4 | baturite
# Processing Record 1 of Set 5 | curvelo
# Processing Record 2 of Set 5 | suhbaatar
# Processing Record 3 of Set 5 | nabire
# Processing Record 4 of Set 5 | amapa
# Processing Record 5 of Set 5 | chandbali
# Processing Record 6 of Set 5 | naze
# Processing Record 7 of Set 5 | batticaloa
# Processing Record 8 of Set 5 | samarai
# Processing Record 9 of Set 5 | kaitangata
# Processing Record 10 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 5 | emilio carranza
# Processing Record 12 of Set 5 | liverpool
# Processing Record 13 of Set 5 | katsuura
# Processing Record 14 of Set 5 | dibulla
# Processing Record 15 of Set 5 | tilichiki
# Processing Record 16 of Set 5 | mikhaylovka
# Processing Record 17 of Set 5 | esperance
# Processing Record 18 of Set 5 | marsh harbour
# Processing Record 19 of Set 5 | kandrian
# Processing Record 20 of Set 5 | moba
# Processing Record 21 of Set 5 | torbay
# Processing Record 22 of Set 5 | ipeti
# City not found. Skipping...
# Processing Record 23 of Set 5 | kedrovyy
# Processing Record 24 of Set 5 | iki-burul
# Processing Record 25 of Set 5 | acarau
# Processing Record 26 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 5 | isangel
# Processing Record 29 of Set 5 | adre
# Processing Record 30 of Set 5 | urzhum
# Processing Record 31 of Set 5 | havre-saint-pierre
# Processing Record 32 of Set 5 | aklavik
# Processing Record 33 of Set 5 | kampene
# Processing Record 34 of Set 5 | cabo san lucas
# Processing Record 35 of Set 5 | longkou
# Processing Record 36 of Set 5 | dori
# Processing Record 37 of Set 5 | mizdah
# Processing Record 38 of Set 5 | punto fijo
# Processing Record 39 of Set 5 | kisangani
# Processing Record 40 of Set 5 | gobabis
# Processing Record 41 of Set 5 | mokhsogollokh
# Processing Record 42 of Set 5 | moanda
# Processing Record 43 of Set 5 | berbera
# Processing Record 44 of Set 5 | thinadhoo
# Processing Record 45 of Set 5 | beloha
# Processing Record 46 of Set 5 | araouane
# Processing Record 47 of Set 5 | neyshabur
# Processing Record 48 of Set 5 | makakilo city
# Processing Record 49 of Set 5 | moose factory
# Processing Record 50 of Set 5 | itarema
# Processing Record 1 of Set 6 | kushima
# Processing Record 2 of Set 6 | pallasovka
# Processing Record 3 of Set 6 | jardim
# Processing Record 4 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 6 | phagwara
# Processing Record 6 of Set 6 | dalnegorsk
# Processing Record 7 of Set 6 | pisco
# Processing Record 8 of Set 6 | yerbogachen
# Processing Record 9 of Set 6 | portland
# Processing Record 10 of Set 6 | bonthe
# Processing Record 11 of Set 6 | camacupa
# Processing Record 12 of Set 6 | vrede
# Processing Record 13 of Set 6 | tommot
# Processing Record 14 of Set 6 | ostrovnoy
# Processing Record 15 of Set 6 | san joaquin
# Processing Record 16 of Set 6 | gawler
# Processing Record 17 of Set 6 | boyolangu
# Processing Record 18 of Set 6 | codajas
# Processing Record 19 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 20 of Set 6 | chicama
# Processing Record 21 of Set 6 | puerto cabezas
# Processing Record 22 of Set 6 | bad neustadt
# City not found. Skipping...
# Processing Record 23 of Set 6 | quebo
# Processing Record 24 of Set 6 | kirakira
# Processing Record 25 of Set 6 | mudhol
# Processing Record 26 of Set 6 | quchan
# Processing Record 27 of Set 6 | constitucion
# Processing Record 28 of Set 6 | sept-iles
# Processing Record 29 of Set 6 | ariquemes
# Processing Record 30 of Set 6 | tymovskoye
# Processing Record 31 of Set 6 | sitio novo do tocantins
# Processing Record 32 of Set 6 | san cristobal
# Processing Record 33 of Set 6 | pokhara
# Processing Record 34 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 6 | pevek
# Processing Record 36 of Set 6 | bredasdorp
# Processing Record 37 of Set 6 | pamyat parizhskoy kommuny
# Processing Record 38 of Set 6 | eslamshahr
# Processing Record 39 of Set 6 | guerrero negro
# Processing Record 40 of Set 6 | tura
# Processing Record 41 of Set 6 | masuguru
# Processing Record 42 of Set 6 | kushmurun
# Processing Record 43 of Set 6 | dingle
# Processing Record 44 of Set 6 | domoni
# Processing Record 45 of Set 6 | lasa
# Processing Record 46 of Set 6 | wad rawah
# Processing Record 47 of Set 6 | tiksi
# Processing Record 48 of Set 6 | paris
# Processing Record 49 of Set 6 | whitianga
# Processing Record 50 of Set 6 | auki
# Processing Record 1 of Set 7 | charters towers
# Processing Record 2 of Set 7 | markova
# Processing Record 3 of Set 7 | shelburne
# Processing Record 4 of Set 7 | saraipali
# Processing Record 5 of Set 7 | olafsvik
# Processing Record 6 of Set 7 | nemuro
# Processing Record 7 of Set 7 | rockport
# Processing Record 8 of Set 7 | troitskoye
# Processing Record 9 of Set 7 | saint-francois
# Processing Record 10 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 7 | misratah
# Processing Record 12 of Set 7 | bom jardim
# Processing Record 13 of Set 7 | myrhorod
# Processing Record 14 of Set 7 | kahului
# Processing Record 15 of Set 7 | vredendal
# Processing Record 16 of Set 7 | valdivia
# Processing Record 17 of Set 7 | kuryk
# Processing Record 18 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 7 | san quintin
# Processing Record 20 of Set 7 | ndioum
# Processing Record 21 of Set 7 | broome
# Processing Record 22 of Set 7 | pandan
# Processing Record 23 of Set 7 | penzance
# Processing Record 24 of Set 7 | castro
# Processing Record 25 of Set 7 | roald
# Processing Record 26 of Set 7 | bara
# Processing Record 27 of Set 7 | lodja
# Processing Record 28 of Set 7 | abapo
# Processing Record 29 of Set 7 | avera
# Processing Record 30 of Set 7 | riyadh
# Processing Record 31 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 7 | talnakh
# Processing Record 35 of Set 7 | loei
# Processing Record 36 of Set 7 | oriximina
# Processing Record 37 of Set 7 | pangnirtung
# Processing Record 38 of Set 7 | kargil
# Processing Record 39 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 40 of Set 7 | evanston
# Processing Record 41 of Set 7 | ende
# Processing Record 42 of Set 7 | ribeira grande
# Processing Record 43 of Set 7 | kavieng
# Processing Record 44 of Set 7 | chore
# City not found. Skipping...
# Processing Record 45 of Set 7 | vila
# Processing Record 46 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 7 | alice springs
# Processing Record 48 of Set 7 | asau
# Processing Record 49 of Set 7 | viamao
# Processing Record 50 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 8 | rawson
# Processing Record 2 of Set 8 | wuxue
# Processing Record 3 of Set 8 | hay river
# Processing Record 4 of Set 8 | georgetown
# Processing Record 5 of Set 8 | saint-philippe
# Processing Record 6 of Set 8 | fairbanks
# Processing Record 7 of Set 8 | coquimbo
# Processing Record 8 of Set 8 | noshiro
# Processing Record 9 of Set 8 | codrington
# Processing Record 10 of Set 8 | calama
# Processing Record 11 of Set 8 | sawtell
# Processing Record 12 of Set 8 | vaitape
# Processing Record 13 of Set 8 | tandil
# Processing Record 14 of Set 8 | guozhen
# Processing Record 15 of Set 8 | cangzhou
# Processing Record 16 of Set 8 | namatanai
# Processing Record 17 of Set 8 | aswan
# Processing Record 18 of Set 8 | saint-georges
# Processing Record 19 of Set 8 | kortkeros
# Processing Record 20 of Set 8 | vernon
# Processing Record 21 of Set 8 | yar-sale
# Processing Record 22 of Set 8 | riohacha
# Processing Record 23 of Set 8 | key west
# Processing Record 24 of Set 8 | kenai
# Processing Record 25 of Set 8 | singkawang
# Processing Record 26 of Set 8 | polunochnoye
# Processing Record 27 of Set 8 | tiznit
# Processing Record 28 of Set 8 | hamilton
# Processing Record 29 of Set 8 | hambantota
# Processing Record 30 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 8 | pimenta bueno
# Processing Record 32 of Set 8 | niamtougou
# Processing Record 33 of Set 8 | yerofey pavlovich
# Processing Record 34 of Set 8 | simao
# Processing Record 35 of Set 8 | khvorostyanka
# Processing Record 36 of Set 8 | clive
# Processing Record 37 of Set 8 | honavar
# Processing Record 38 of Set 8 | cochrane
# Processing Record 39 of Set 8 | clyde river
# Processing Record 40 of Set 8 | ouesso
# Processing Record 41 of Set 8 | jacqueville
# Processing Record 42 of Set 8 | livingston
# Processing Record 43 of Set 8 | mount gambier
# Processing Record 44 of Set 8 | norrtalje
# Processing Record 45 of Set 8 | celestun
# Processing Record 46 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 8 | erenhot
# Processing Record 48 of Set 8 | beoumi
# Processing Record 49 of Set 8 | narsaq
# Processing Record 50 of Set 8 | onokhoy
# Processing Record 1 of Set 9 | kassala
# Processing Record 2 of Set 9 | sola
# Processing Record 3 of Set 9 | ibra
# Processing Record 4 of Set 9 | omboue
# Processing Record 5 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 9 | hailey
# Processing Record 7 of Set 9 | zhob
# Processing Record 8 of Set 9 | gandu
# Processing Record 9 of Set 9 | burdur
# Processing Record 10 of Set 9 | svetlyy
# Processing Record 11 of Set 9 | gemena
# Processing Record 12 of Set 9 | maniwaki
# Processing Record 13 of Set 9 | ulagan
# Processing Record 14 of Set 9 | vanimo
# Processing Record 15 of Set 9 | kalmunai
# Processing Record 16 of Set 9 | yeppoon
# Processing Record 17 of Set 9 | sidi ali
# Processing Record 18 of Set 9 | alekseyevka
# Processing Record 19 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 20 of Set 9 | meadow lake
# Processing Record 21 of Set 9 | brae
# Processing Record 22 of Set 9 | payyannur
# Processing Record 23 of Set 9 | natal
# Processing Record 24 of Set 9 | jumla
# Processing Record 25 of Set 9 | schio
# Processing Record 26 of Set 9 | luganville
# Processing Record 27 of Set 9 | yangjiang
# Processing Record 28 of Set 9 | muroto
# Processing Record 29 of Set 9 | praxedis guerrero
# Processing Record 30 of Set 9 | marsa matruh
# Processing Record 31 of Set 9 | agadez
# Processing Record 32 of Set 9 | karratha
# Processing Record 33 of Set 9 | verkhoyansk
# Processing Record 34 of Set 9 | touros
# Processing Record 35 of Set 9 | belaya gora
# Processing Record 36 of Set 9 | dwarka
# Processing Record 37 of Set 9 | krasnogorskoye
# Processing Record 38 of Set 9 | nianzishan
# Processing Record 39 of Set 9 | iwanai
# Processing Record 40 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 41 of Set 9 | wajir
# Processing Record 42 of Set 9 | te anau
# Processing Record 43 of Set 9 | ancud
# Processing Record 44 of Set 9 | alofi
# Processing Record 45 of Set 9 | mitsamiouli
# Processing Record 46 of Set 9 | teacapan
# Processing Record 47 of Set 9 | voznesenskoye
# Processing Record 48 of Set 9 | leningradskiy
# Processing Record 49 of Set 9 | warrnambool
# Processing Record 50 of Set 9 | camocim
# Processing Record 1 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 2 of Set 10 | faya
# Processing Record 3 of Set 10 | male
# Processing Record 4 of Set 10 | ibimirim
# Processing Record 5 of Set 10 | taltal
# Processing Record 6 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 10 | mandalgovi
# Processing Record 8 of Set 10 | coahuayana
# Processing Record 9 of Set 10 | narasannapeta
# Processing Record 10 of Set 10 | bandarbeyla
# Processing Record 11 of Set 10 | faanui
# Processing Record 12 of Set 10 | namibe
# Processing Record 13 of Set 10 | svetlaya
# Processing Record 14 of Set 10 | dhidhdhoo
# Processing Record 15 of Set 10 | mount pleasant
# Processing Record 16 of Set 10 | broken hill
# Processing Record 17 of Set 10 | gunzenhausen
# Processing Record 18 of Set 10 | sao jose da coroa grande
# Processing Record 19 of Set 10 | bud
# Processing Record 20 of Set 10 | ascoli piceno
# Processing Record 21 of Set 10 | tuy hoa
# Processing Record 22 of Set 10 | hanna
# Processing Record 23 of Set 10 | baijiantan
# Processing Record 24 of Set 10 | northfield
# Processing Record 25 of Set 10 | saint-pierre
# Processing Record 26 of Set 10 | ayan
# Processing Record 27 of Set 10 | lata
# Processing Record 28 of Set 10 | severo-kurilsk
# Processing Record 29 of Set 10 | moron
# Processing Record 30 of Set 10 | borogontsy
# Processing Record 31 of Set 10 | santa fe do sul
# Processing Record 32 of Set 10 | matara
# Processing Record 33 of Set 10 | vikhorevka
# Processing Record 34 of Set 10 | kalmar
# Processing Record 35 of Set 10 | kyabe
# Processing Record 36 of Set 10 | raga
# Processing Record 37 of Set 10 | port hardy
# Processing Record 38 of Set 10 | caravelas
# Processing Record 39 of Set 10 | abu dhabi
# Processing Record 40 of Set 10 | mezhdurechensk
# Processing Record 41 of Set 10 | turbat
# Processing Record 42 of Set 10 | port lincoln
# Processing Record 43 of Set 10 | itoman
# Processing Record 44 of Set 10 | farap
# Processing Record 45 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 46 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 10 | fort abbas
# Processing Record 48 of Set 10 | taksimo
# Processing Record 49 of Set 10 | vao
# Processing Record 50 of Set 10 | juruti
# Processing Record 1 of Set 11 | biak
# Processing Record 2 of Set 11 | burnie
# Processing Record 3 of Set 11 | pouembout
# Processing Record 4 of Set 11 | neryungri
# Processing Record 5 of Set 11 | alihe
# Processing Record 6 of Set 11 | opuwo
# Processing Record 7 of Set 11 | pitimbu
# Processing Record 8 of Set 11 | sorkjosen
# Processing Record 9 of Set 11 | filingue
# Processing Record 10 of Set 11 | arica
# Processing Record 11 of Set 11 | aksu
# Processing Record 12 of Set 11 | iqaluit
# Processing Record 13 of Set 11 | aasiaat
# Processing Record 14 of Set 11 | bardiyah
# Processing Record 15 of Set 11 | yarega
# Processing Record 16 of Set 11 | beringovskiy
# Processing Record 17 of Set 11 | chimore
# Processing Record 18 of Set 11 | manaus
# Processing Record 19 of Set 11 | trinidad
# Processing Record 20 of Set 11 | colon
# Processing Record 21 of Set 11 | acapulco
# Processing Record 22 of Set 11 | havelock
# Processing Record 23 of Set 11 | miles city
# Processing Record 24 of Set 11 | cap malheureux
# Processing Record 25 of Set 11 | haines junction
# Processing Record 26 of Set 11 | margate
# Processing Record 27 of Set 11 | port hawkesbury
# Processing Record 28 of Set 11 | surt
# Processing Record 29 of Set 11 | egvekinot
# Processing Record 30 of Set 11 | anadyr
# Processing Record 31 of Set 11 | shache
# Processing Record 32 of Set 11 | baghdad
# Processing Record 33 of Set 11 | dordrecht
# Processing Record 34 of Set 11 | sabha
# Processing Record 35 of Set 11 | rongcheng
# Processing Record 36 of Set 11 | vestmannaeyjar
# Processing Record 37 of Set 11 | tautira
# Processing Record 38 of Set 11 | morgan city
# Processing Record 39 of Set 11 | polyarnyy
# Processing Record 40 of Set 11 | sao joao da barra
# Processing Record 41 of Set 11 | kutum
# Processing Record 42 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 11 | yertsevo
# Processing Record 44 of Set 11 | livonia
# Processing Record 45 of Set 11 | waterloo
# Processing Record 46 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 11 | maputo
# Processing Record 48 of Set 11 | kayes
# Processing Record 49 of Set 11 | yarada
# Processing Record 50 of Set 11 | rochester
# Processing Record 1 of Set 12 | akyab
# Processing Record 2 of Set 12 | ko samui
# Processing Record 3 of Set 12 | magadan
# Processing Record 4 of Set 12 | melbu
# Processing Record 5 of Set 12 | hofn
# Processing Record 6 of Set 12 | bilibino
# Processing Record 7 of Set 12 | nador
# Processing Record 8 of Set 12 | riberalta
# Processing Record 9 of Set 12 | sirawai
# Processing Record 10 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 11 of Set 12 | kembe
# Processing Record 12 of Set 12 | tongliao
# Processing Record 13 of Set 12 | mount isa
# Processing Record 14 of Set 12 | yambio
# Processing Record 15 of Set 12 | mitu
# Processing Record 16 of Set 12 | shkotovo-26
# City not found. Skipping...
# Processing Record 17 of Set 12 | sunndalsora
# Processing Record 18 of Set 12 | praia
# Processing Record 19 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 20 of Set 12 | antofagasta
# Processing Record 21 of Set 12 | harare
# Processing Record 22 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 12 | muchkapskiy
# Processing Record 24 of Set 12 | santa lucia
# Processing Record 25 of Set 12 | turukhansk
# Processing Record 26 of Set 12 | saint-paul
# Processing Record 27 of Set 12 | tandalti
# Processing Record 28 of Set 12 | grenaa
# Processing Record 29 of Set 12 | sorong
# Processing Record 30 of Set 12 | nanortalik
# Processing Record 31 of Set 12 | freeport
# Processing Record 32 of Set 12 | iranshahr
# Processing Record 33 of Set 12 | hikone
# Processing Record 34 of Set 12 | artesia
# Processing Record 35 of Set 12 | meulaboh
# Processing Record 36 of Set 12 | pangoa
# Processing Record 37 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 12 | saint-denis
# Processing Record 39 of Set 12 | vranov
# Processing Record 40 of Set 12 | barabai
# Processing Record 41 of Set 12 | fortuna
# Processing Record 42 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 43 of Set 12 | dicabisagan
# Processing Record 44 of Set 12 | moerai
# Processing Record 45 of Set 12 | aguas vermelhas
# Processing Record 46 of Set 12 | buzmeyin
# Processing Record 47 of Set 12 | redlands
# Processing Record 48 of Set 12 | babahoyo
# Processing Record 49 of Set 12 | edremit
# Processing Record 50 of Set 12 | santa fe
# Processing Record 1 of Set 13 | lotofaga
# Processing Record 2 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 3 of Set 13 | roebourne
# Processing Record 4 of Set 13 | chorozinho
# Processing Record 5 of Set 13 | les escoumins
# Processing Record 6 of Set 13 | ayorou
# Processing Record 7 of Set 13 | korisos
# Processing Record 8 of Set 13 | otradnoye
# Processing Record 9 of Set 13 | severnyy
# Processing Record 10 of Set 13 | yichang
# Processing Record 11 of Set 13 | barra patuca
# Processing Record 12 of Set 13 | paka
# Processing Record 13 of Set 13 | zverinogolovskoye
# Processing Record 14 of Set 13 | srednekolymsk
# Processing Record 15 of Set 13 | black river
# Processing Record 16 of Set 13 | srandakan
# Processing Record 17 of Set 13 | lisieux
# Processing Record 18 of Set 13 | lugovoy
# Processing Record 19 of Set 13 | tomatlan
# Processing Record 20 of Set 13 | shu
# Processing Record 21 of Set 13 | port hedland
# Processing Record 22 of Set 13 | bakau
# Processing Record 23 of Set 13 | ranong
# Processing Record 24 of Set 13 | mezen
# Processing Record 25 of Set 13 | pirapo
# Processing Record 26 of Set 13 | thurso
# Processing Record 27 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 13 | zyryanka
# Processing Record 29 of Set 13 | kothapet
# Processing Record 30 of Set 13 | tinskoy
# Processing Record 31 of Set 13 | billings
# Processing Record 32 of Set 13 | qarayeri
# Processing Record 33 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 34 of Set 13 | rincon
# Processing Record 35 of Set 13 | kolokani
# Processing Record 36 of Set 13 | axim
# Processing Record 37 of Set 13 | tsiroanomandidy
# Processing Record 38 of Set 13 | scottsbluff
# Processing Record 39 of Set 13 | krynychky
# Processing Record 40 of Set 13 | orbetello
# Processing Record 41 of Set 13 | esna
# Processing Record 42 of Set 13 | phrai bung
# City not found. Skipping...
# Processing Record 43 of Set 13 | cascais
# Processing Record 44 of Set 13 | jutai
# Processing Record 45 of Set 13 | hobyo
# Processing Record 46 of Set 13 | aksarka
# Processing Record 47 of Set 13 | halifax
# Processing Record 48 of Set 13 | caarapo
# Processing Record 49 of Set 13 | mbanza-ngungu
# Processing Record 50 of Set 13 | gat
# Processing Record 1 of Set 14 | cerritos
# Processing Record 2 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 14 | comodoro rivadavia
# Processing Record 4 of Set 14 | point fortin
# Processing Record 5 of Set 14 | linxi
# Processing Record 6 of Set 14 | ulefoss
# Processing Record 7 of Set 14 | fare
# Processing Record 8 of Set 14 | galveston
# Processing Record 9 of Set 14 | ahuimanu
# Processing Record 10 of Set 14 | ossora
# Processing Record 11 of Set 14 | svetlogorsk
# Processing Record 12 of Set 14 | koumac
# Processing Record 13 of Set 14 | vallenar
# Processing Record 14 of Set 14 | privokzalnyy
# City not found. Skipping...
# Processing Record 15 of Set 14 | russell
# Processing Record 16 of Set 14 | abomsa
# Processing Record 17 of Set 14 | smolenka
# Processing Record 18 of Set 14 | esmeraldas
# Processing Record 19 of Set 14 | tromso
# Processing Record 20 of Set 14 | swellendam
# Processing Record 21 of Set 14 | pangody
# Processing Record 22 of Set 14 | yelkhovka
# Processing Record 23 of Set 14 | ube
# Processing Record 24 of Set 14 | alugan
# Processing Record 25 of Set 14 | odweyne
# Processing Record 26 of Set 14 | mudgee
# Processing Record 27 of Set 14 | evensk
# Processing Record 28 of Set 14 | duluth
# Processing Record 29 of Set 14 | chake chake
# Processing Record 30 of Set 14 | vitimskiy
# City not found. Skipping...
# Processing Record 31 of Set 14 | gwadar
# Processing Record 32 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 33 of Set 14 | bukachacha
# Processing Record 34 of Set 14 | lac du bonnet
# Processing Record 35 of Set 14 | murindo
# Processing Record 36 of Set 14 | berdigestyakh
# Processing Record 37 of Set 14 | khandyga
# Processing Record 38 of Set 14 | ulaangom
# Processing Record 39 of Set 14 | olavarria
# Processing Record 40 of Set 14 | nome
# Processing Record 41 of Set 14 | hovd
# Processing Record 42 of Set 14 | wanaka
# Processing Record 43 of Set 14 | aksay
# Processing Record 44 of Set 14 | elko
# Processing Record 45 of Set 14 | lencois paulista
# Processing Record 46 of Set 14 | calbuco
# Processing Record 47 of Set 14 | rio grande
# Processing Record 48 of Set 14 | silvino lobos
# Processing Record 49 of Set 14 | sampit
# Processing Record 50 of Set 14 | chulman
# Processing Record 1 of Set 15 | kodinsk
# Processing Record 2 of Set 15 | okha
# Processing Record 3 of Set 15 | guarizama
# Processing Record 4 of Set 15 | umm lajj
# Processing Record 5 of Set 15 | kumluca
# Processing Record 6 of Set 15 | idrinskoye
# Processing Record 7 of Set 15 | gyongyostarjan
# Processing Record 8 of Set 15 | northam
# Processing Record 9 of Set 15 | ambanja
# Processing Record 10 of Set 15 | salalah
# Processing Record 11 of Set 15 | samoded
# Processing Record 12 of Set 15 | the valley
# Processing Record 13 of Set 15 | eyl
# Processing Record 14 of Set 15 | kiama
# Processing Record 15 of Set 15 | owando
# Processing Record 16 of Set 15 | vostok
# Processing Record 17 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 18 of Set 15 | sao felix do xingu
# Processing Record 19 of Set 15 | penticton
# Processing Record 20 of Set 15 | santa ana
# Processing Record 21 of Set 15 | rio gallegos
# Processing Record 22 of Set 15 | oranjestad
# Processing Record 23 of Set 15 | soe
# Processing Record 24 of Set 15 | nizhniy kuranakh
# Processing Record 25 of Set 15 | alta floresta
# Processing Record 26 of Set 15 | vershino-darasunskiy
# Processing Record 27 of Set 15 | gbadolite
# Processing Record 28 of Set 15 | camana
# Processing Record 29 of Set 15 | manokwari
# Processing Record 30 of Set 15 | inverell
# Processing Record 31 of Set 15 | mgandu
# Processing Record 32 of Set 15 | quatre cocos
# Processing Record 33 of Set 15 | sorland
# Processing Record 34 of Set 15 | nicoya
# Processing Record 35 of Set 15 | sarangani
# Processing Record 36 of Set 15 | aksha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 676

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora      EC  -0.7393  -90.3518     67.55        97          89
# 1        Camopi      GF   3.1655  -52.3158     73.24       100         100
# 2      Hermanus      ZA -34.4187   19.2345     78.91        81          93
# 3          Hilo      US  19.7297 -155.0900     70.79        43          90
# 4      Khatanga      RU  71.9667  102.5000    -27.62        93          99
# 5      Goderich      CA  43.7501  -81.7165     42.21        65         100
# 6        Atuona      PF  -9.8000 -139.0333     78.66        78          39
# 7         Minsk      BY  53.9000   27.5667     31.75        83         100
# 8  Longyearbyen      SJ  78.2186   15.6401     31.84        74          40
# 9         Kapaa      US  22.0752 -159.3190     75.52        73          40
#
#    Wind Speed Current Description
# 0        7.83     overcast clouds
# 1        0.96     overcast clouds
# 2       10.36     overcast clouds
# 3        4.61          light rain
# 4       11.39     overcast clouds
# 5       16.11     overcast clouds
# 6       21.74          light rain
# 7        7.99     overcast clouds
# 8       21.85    scattered clouds
# 9        4.00    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
